# %% [markdown]
# # Image features exercise
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# We have seen that we can achieve reasonable performance on an image classification task by training a linear classifier on the pixels of the input image. In this exercise we will show that we can improve our classification performance by training linear classifiers not on raw pixels but on features that are computed from the raw pixels.
#
# All of your work for this exercise will be done in this notebook.

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

from __future__ import print_function

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Load data
# Similar to previous exercises, we will load CIFAR-10 data from disk.

# %%
from cs231n.features import color_histogram_hsv, hog_feature

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # Subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    
    return X_train, y_train, X_val, y_val, X_test, y_test

X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()

# %% [markdown]
# ## Extract Features
# For each image we will compute a Histogram of Oriented
# Gradients (HOG) as well as a color histogram using the hue channel in HSV
# color space. We form our final feature vector for each image by concatenating
# the HOG and color histogram feature vectors.
#
# Roughly speaking, HOG should capture the texture of the image while ignoring
# color information, and the color histogram represents the color of the input
# image while ignoring texture. As a result, we expect that using both together
# ought to work better than using either alone. Verifying this assumption would
# be a good thing to try for the bonus section.
#
# The `hog_feature` and `color_histogram_hsv` functions both operate on a single
# image and return a feature vector for that image. The extract_features
# function takes a set of images and a list of feature functions and evaluates
# each feature function on each image, storing the results in a matrix where
# each column is the concatenation of all feature vectors for a single image.

# %%
from cs231n.features import *

num_color_bins = 10 # Number of bins in the color histogram
feature_fns = [hog_feature, lambda img: color_histogram_hsv(img, nbin=num_color_bins)]
X_train_feats = extract_features(X_train, feature_fns, verbose=True)
X_val_feats = extract_features(X_val, feature_fns)
X_test_feats = extract_features(X_test, feature_fns)

# Preprocessing: Subtract the mean feature
mean_feat = np.mean(X_train_feats, axis=0, keepdims=True)
X_train_feats -= mean_feat
X_val_feats -= mean_feat
X_test_feats -= mean_feat

# Preprocessing: Divide by standard deviation. This ensures that each feature
# has roughly the same scale.
std_feat = np.std(X_train_feats, axis=0, keepdims=True)
X_train_feats /= std_feat
X_val_feats /= std_feat
X_test_feats /= std_feat

# Preprocessing: Add a bias dimension
X_train_feats = np.hstack([X_train_feats, np.ones((X_train_feats.shape[0], 1))])
X_val_feats = np.hstack([X_val_feats, np.ones((X_val_feats.shape[0], 1))])
X_test_feats = np.hstack([X_test_feats, np.ones((X_test_feats.shape[0], 1))])
# Out:
# Done extracting features for 1000 / 49000 images
# Done extracting features for 2000 / 49000 images
# Done extracting features for 3000 / 49000 images
# Done extracting features for 4000 / 49000 images
# Done extracting features for 5000 / 49000 images
# Done extracting features for 6000 / 49000 images
# Done extracting features for 7000 / 49000 images
# Done extracting features for 8000 / 49000 images
# Done extracting features for 9000 / 49000 images
# Done extracting features for 10000 / 49000 images
# Done extracting features for 11000 / 49000 images
# Done extracting features for 12000 / 49000 images
# Done extracting features for 13000 / 49000 images
# Done extracting features for 14000 / 49000 images
# Done extracting features for 15000 / 49000 images
# Done extracting features for 16000 / 49000 images
# Done extracting features for 17000 / 49000 images
# Done extracting features for 18000 / 49000 images
# Done extracting features for 19000 / 49000 images
# Done extracting features for 20000 / 49000 images
# Done extracting features for 21000 / 49000 images
# Done extracting features for 22000 / 49000 images
# Done extracting features for 23000 / 49000 images
# Done extracting features for 24000 / 49000 images
# Done extracting features for 25000 / 49000 images
# Done extracting features for 26000 / 49000 images
# Done extracting features for 27000 / 49000 images
# Done extracting features for 28000 / 49000 images
# Done extracting features for 29000 / 49000 images
# Done extracting features for 30000 / 49000 images
# Done extracting features for 31000 / 49000 images
# Done extracting features for 32000 / 49000 images
# Done extracting features for 33000 / 49000 images
# Done extracting features for 34000 / 49000 images
# Done extracting features for 35000 / 49000 images
# Done extracting features for 36000 / 49000 images
# Done extracting features for 37000 / 49000 images
# Done extracting features for 38000 / 49000 images
# Done extracting features for 39000 / 49000 images
# Done extracting features for 40000 / 49000 images
# Done extracting features for 41000 / 49000 images
# Done extracting features for 42000 / 49000 images
# Done extracting features for 43000 / 49000 images
# Done extracting features for 44000 / 49000 images
# Done extracting features for 45000 / 49000 images
# Done extracting features for 46000 / 49000 images
# Done extracting features for 47000 / 49000 images
# Done extracting features for 48000 / 49000 images

# %% [markdown]
# ## Train SVM on features
# Using the multiclass SVM code developed earlier in the assignment, train SVMs on top of the features extracted above; this should achieve better results than training SVMs directly on top of raw pixels.

# %%
# Use the validation set to tune the learning rate and regularization strength

from cs231n.classifiers.linear_classifier import LinearSVM

learning_rates = [1e-9, 2.5e-9, 5e-9, 7.5e-9, 1e-8, 1.25e-8]
regularization_strengths = [1e6, 2e6, 3e6, 4e6, 5e6, 6e6, 7e6, 8e6, 9e6]

num_iters = 1500

results = {}
best_val = -1
best_svm = None

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained classifer in best_svm. You might also want to play          #
# with different numbers of bins in the color histogram. If you are careful    #
# you should be able to get accuracy of near 0.44 on the validation set.       #
################################################################################
for lr in learning_rates:
    for reg in regularization_strengths:
        svm = LinearSVM()
        loss_hist = svm.train(X_train_feats, y_train, learning_rate=lr, reg=reg,
                              num_iters=num_iters, verbose=False)
        y_train_pred = svm.predict(X_train_feats)
        y_val_pred = svm.predict(X_val_feats)
        train_accuracy = np.mean(y_train == y_train_pred)
        val_accuracy = np.mean(y_val == y_val_pred)
        results[(lr, reg)] = (train_accuracy, val_accuracy)
        if val_accuracy > best_val:
            best_val = val_accuracy
            best_svm = svm
################################################################################
#                              END OF YOUR CODE                                #
################################################################################

# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# lr 1.000000e-09 reg 1.000000e+06 train accuracy: 0.093327 val accuracy: 0.093000
# lr 1.000000e-09 reg 2.000000e+06 train accuracy: 0.133184 val accuracy: 0.141000
# lr 1.000000e-09 reg 3.000000e+06 train accuracy: 0.231490 val accuracy: 0.231000
# lr 1.000000e-09 reg 4.000000e+06 train accuracy: 0.406286 val accuracy: 0.399000
# lr 1.000000e-09 reg 5.000000e+06 train accuracy: 0.418102 val accuracy: 0.423000
# lr 1.000000e-09 reg 6.000000e+06 train accuracy: 0.412143 val accuracy: 0.408000
# lr 1.000000e-09 reg 7.000000e+06 train accuracy: 0.411020 val accuracy: 0.405000
# lr 1.000000e-09 reg 8.000000e+06 train accuracy: 0.410694 val accuracy: 0.402000
# lr 1.000000e-09 reg 9.000000e+06 train accuracy: 0.414143 val accuracy: 0.412000
# lr 2.500000e-09 reg 1.000000e+06 train accuracy: 0.209735 val accuracy: 0.240000
# lr 2.500000e-09 reg 2.000000e+06 train accuracy: 0.413245 val accuracy: 0.415000
# lr 2.500000e-09 reg 3.000000e+06 train accuracy: 0.413857 val accuracy: 0.426000
# lr 2.500000e-09 reg 4.000000e+06 train accuracy: 0.411551 val accuracy: 0.402000
# lr 2.500000e-09 reg 5.000000e+06 train accuracy: 0.408490 val accuracy: 0.409000
# lr 2.500000e-09 reg 6.000000e+06 train accuracy: 0.410265 val accuracy: 0.406000
# lr 2.500000e-09 reg 7.000000e+06 train accuracy: 0.404224 val accuracy: 0.400000
# lr 2.500000e-09 reg 8.000000e+06 train accuracy: 0.411633 val accuracy: 0.426000
# lr 2.500000e-09 reg 9.000000e+06 train accuracy: 0.417224 val accuracy: 0.427000
# lr 5.000000e-09 reg 1.000000e+06 train accuracy: 0.415918 val accuracy: 0.422000
# lr 5.000000e-09 reg 2.000000e+06 train accuracy: 0.408143 val accuracy: 0.398000
# lr 5.000000e-09 reg 3.000000e+06 train accuracy: 0.414694 val accuracy: 0.417000
# lr 5.000000e-09 reg 4.000000e+06 train accuracy: 0.411347 val accuracy: 0.422000
# lr 5.000000e-09 reg 5.000000e+06 train accuracy: 0.402980 val accuracy: 0.395000
# lr 5.000000e-09 reg 6.000000e+06 train accuracy: 0.409245 val accuracy: 0.401000
# lr 5.000000e-09 reg 7.000000e+06 train accuracy: 0.402347 val accuracy: 0.402000
# lr 5.000000e-09 reg 8.000000e+06 train accuracy: 0.407286 val accuracy: 0.394000
# lr 5.000000e-09 reg 9.000000e+06 train accuracy: 0.414612 val accuracy: 0.409000
# lr 7.500000e-09 reg 1.000000e+06 train accuracy: 0.418592 val accuracy: 0.419000
# lr 7.500000e-09 reg 2.000000e+06 train accuracy: 0.410592 val accuracy: 0.413000
# lr 7.500000e-09 reg 3.000000e+06 train accuracy: 0.416388 val accuracy: 0.417000
# lr 7.500000e-09 reg 4.000000e+06 train accuracy: 0.409980 val accuracy: 0.408000
# lr 7.500000e-09 reg 5.000000e+06 train accuracy: 0.412510 val accuracy: 0.421000
# lr 7.500000e-09 reg 6.000000e+06 train accuracy: 0.408714 val accuracy: 0.397000
# lr 7.500000e-09 reg 7.000000e+06 train accuracy: 0.405122 val accuracy: 0.412000
# lr 7.500000e-09 reg 8.000000e+06 train accuracy: 0.406633 val accuracy: 0.406000
# lr 7.500000e-09 reg 9.000000e+06 train accuracy: 0.401041 val accuracy: 0.401000
# lr 1.000000e-08 reg 1.000000e+06 train accuracy: 0.412204 val accuracy: 0.426000
# lr 1.000000e-08 reg 2.000000e+06 train accuracy: 0.414612 val accuracy: 0.409000
# lr 1.000000e-08 reg 3.000000e+06 train accuracy: 0.410163 val accuracy: 0.396000
# lr 1.000000e-08 reg 4.000000e+06 train accuracy: 0.413388 val accuracy: 0.404000
# lr 1.000000e-08 reg 5.000000e+06 train accuracy: 0.404000 val accuracy: 0.396000
# lr 1.000000e-08 reg 6.000000e+06 train accuracy: 0.403388 val accuracy: 0.385000
# lr 1.000000e-08 reg 7.000000e+06 train accuracy: 0.399286 val accuracy: 0.411000
# lr 1.000000e-08 reg 8.000000e+06 train accuracy: 0.397469 val accuracy: 0.395000
# lr 1.000000e-08 reg 9.000000e+06 train accuracy: 0.401980 val accuracy: 0.398000
# lr 1.250000e-08 reg 1.000000e+06 train accuracy: 0.409898 val accuracy: 0.402000
# lr 1.250000e-08 reg 2.000000e+06 train accuracy: 0.415000 val accuracy: 0.394000
# lr 1.250000e-08 reg 3.000000e+06 train accuracy: 0.406959 val accuracy: 0.413000
# lr 1.250000e-08 reg 4.000000e+06 train accuracy: 0.415082 val accuracy: 0.418000
# lr 1.250000e-08 reg 5.000000e+06 train accuracy: 0.398959 val accuracy: 0.398000
# lr 1.250000e-08 reg 6.000000e+06 train accuracy: 0.399980 val accuracy: 0.402000
# lr 1.250000e-08 reg 7.000000e+06 train accuracy: 0.403694 val accuracy: 0.387000
# lr 1.250000e-08 reg 8.000000e+06 train accuracy: 0.390878 val accuracy: 0.374000
# lr 1.250000e-08 reg 9.000000e+06 train accuracy: 0.389694 val accuracy: 0.372000
# best validation accuracy achieved during cross-validation: 0.427000

# %%
# Evaluate your trained SVM on the test set
y_test_pred = best_svm.predict(X_test_feats)
test_accuracy = np.mean(y_test == y_test_pred)
print(test_accuracy)
# Out:
# 0.425

# %%
# An important way to gain intuition about how an algorithm works is to
# visualize the mistakes that it makes. In this visualization, we show examples
# of images that are misclassified by our current system. The first column
# shows images that our system labeled as "plane" but whose true label is
# something other than "plane".

examples_per_class = 8
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for cls, cls_name in enumerate(classes):
    idxs = np.where((y_test != cls) & (y_test_pred == cls))[0]
    idxs = np.random.choice(idxs, examples_per_class, replace=False)
    for i, idx in enumerate(idxs):
        plt.subplot(examples_per_class, len(classes), i * len(classes) + cls + 1)
        plt.imshow(X_test[idx].astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls_name)
plt.show()

# %% [markdown]
# ### Inline question 1:
# Describe the misclassification results that you see. Do they make sense?

# %% [markdown]
# ## Neural Network on image features
# Earlier in this assigment we saw that training a two-layer neural network on raw pixels achieved better classification performance than linear classifiers on raw pixels. In this notebook we have seen that linear classifiers on image features outperform linear classifiers on raw pixels.
#
# For completeness, we should also try training a neural network on image features. This approach should outperform all previous approaches: you should easily be able to achieve over 55% classification accuracy on the test set; our best model achieves about 60% classification accuracy.

# %%
print(X_train_feats.shape)
# Out:
# (49000, 155)

# %%
from cs231n.classifiers.neural_net import TwoLayerNet

input_dim = X_train_feats.shape[1]
hidden_dim = 500
num_classes = 10

learning_rates = [(1+i*0.1) for i in range (-5,5)]
regularization_strengths = [(1+i*0.1)*1e-3 for i in range(-5,5)]

# learning_rates = [3e-1,0.6,0.9]
# regularization_strengths = [1e-4, 4e-4, 1.2e-3, 1.5e-3]

net = TwoLayerNet(input_dim, hidden_dim, num_classes)
best_val = -1
best_net = None
results = {}
################################################################################
# TODO: Train a two-layer neural network on image features. You may want to    #
# cross-validate various parameters as in previous sections. Store your best   #
# model in the best_net variable.                                              #
################################################################################
number_of_models = 0
total = len(learning_rates) * len(regularization_strengths)

for lr in learning_rates:
    for reg in regularization_strengths:
        number_of_models +=1
        print('Number of models: %d / %d' % (number_of_models, total))
        net = TwoLayerNet(input_dim, hidden_dim, num_classes)
        # Train the network
        stats = net.train(X_train_feats, y_train, X_val_feats, y_val,
                    num_iters=2000, batch_size=200,
                    learning_rate=lr, learning_rate_decay=0.95,
                    reg=reg, verbose=False)

        train_acc = (net.predict(X_train_feats) == y_train).mean()
        val_acc = (net.predict(X_val_feats) == y_val).mean()
        results[(lr, reg)] = (train_acc, val_acc)
        if val_acc > best_val:
            best_val = val_acc
            best_net = net
            
# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)

################################################################################
#                              END OF YOUR CODE                                #
################################################################################
# Out:
# Number of models: 1 / 100
# Number of models: 2 / 100
# Number of models: 3 / 100
# Number of models: 4 / 100
# Number of models: 5 / 100
# Number of models: 6 / 100
# Number of models: 7 / 100
# Number of models: 8 / 100
# Number of models: 9 / 100
# Number of models: 10 / 100
# Number of models: 11 / 100
# Number of models: 12 / 100
# Number of models: 13 / 100
# Number of models: 14 / 100
# Number of models: 15 / 100
# Number of models: 16 / 100
# Number of models: 17 / 100
# Number of models: 18 / 100
# Number of models: 19 / 100
# Number of models: 20 / 100
# Number of models: 21 / 100
# Number of models: 22 / 100
# Number of models: 23 / 100
# Number of models: 24 / 100
# Number of models: 25 / 100
# Number of models: 26 / 100
# Number of models: 27 / 100
# Number of models: 28 / 100
# Number of models: 29 / 100
# Number of models: 30 / 100
# Number of models: 31 / 100
# Number of models: 32 / 100
# Number of models: 33 / 100
# Number of models: 34 / 100
# Number of models: 35 / 100
# Number of models: 36 / 100
# Number of models: 37 / 100
# Number of models: 38 / 100
# Number of models: 39 / 100
# Number of models: 40 / 100
# Number of models: 41 / 100
# Number of models: 42 / 100
# Number of models: 43 / 100
# Number of models: 44 / 100
# Number of models: 45 / 100
# Number of models: 46 / 100
# Number of models: 47 / 100
# Number of models: 48 / 100
# Number of models: 49 / 100
# Number of models: 50 / 100
# Number of models: 51 / 100
# Number of models: 52 / 100
# Number of models: 53 / 100
# Number of models: 54 / 100
# Number of models: 55 / 100
# Number of models: 56 / 100
# Number of models: 57 / 100
# Number of models: 58 / 100
# Number of models: 59 / 100
# Number of models: 60 / 100
# Number of models: 61 / 100
# Number of models: 62 / 100
# Number of models: 63 / 100
# Number of models: 64 / 100
# Number of models: 65 / 100
# Number of models: 66 / 100
# Number of models: 67 / 100
# Number of models: 68 / 100
# Number of models: 69 / 100
# Number of models: 70 / 100
# Number of models: 71 / 100
# Number of models: 72 / 100
# Number of models: 73 / 100
# Number of models: 74 / 100
# Number of models: 75 / 100
# Number of models: 76 / 100
# Number of models: 77 / 100
# Number of models: 78 / 100
# Number of models: 79 / 100
# Number of models: 80 / 100
# Number of models: 81 / 100
# Number of models: 82 / 100
# Number of models: 83 / 100
# Number of models: 84 / 100
# Number of models: 85 / 100
# Number of models: 86 / 100
# Number of models: 87 / 100
# Number of models: 88 / 100
# Number of models: 89 / 100
# Number of models: 90 / 100
# Number of models: 91 / 100
# Number of models: 92 / 100
# Number of models: 93 / 100
# Number of models: 94 / 100
# Number of models: 95 / 100
# Number of models: 96 / 100
# Number of models: 97 / 100
# Number of models: 98 / 100
# Number of models: 99 / 100
# Number of models: 100 / 100
# lr 5.000000e-01 reg 5.000000e-04 train accuracy: 0.703122 val accuracy: 0.601000
# lr 5.000000e-01 reg 6.000000e-04 train accuracy: 0.700347 val accuracy: 0.585000
# lr 5.000000e-01 reg 7.000000e-04 train accuracy: 0.687837 val accuracy: 0.596000
# lr 5.000000e-01 reg 8.000000e-04 train accuracy: 0.681796 val accuracy: 0.596000
# lr 5.000000e-01 reg 9.000000e-04 train accuracy: 0.681510 val accuracy: 0.592000
# lr 5.000000e-01 reg 1.000000e-03 train accuracy: 0.673735 val accuracy: 0.609000
# lr 5.000000e-01 reg 1.100000e-03 train accuracy: 0.677143 val accuracy: 0.595000
# lr 5.000000e-01 reg 1.200000e-03 train accuracy: 0.668714 val accuracy: 0.593000
# lr 5.000000e-01 reg 1.300000e-03 train accuracy: 0.672837 val accuracy: 0.588000
# lr 5.000000e-01 reg 1.400000e-03 train accuracy: 0.664327 val accuracy: 0.577000
# lr 6.000000e-01 reg 5.000000e-04 train accuracy: 0.716959 val accuracy: 0.595000
# lr 6.000000e-01 reg 6.000000e-04 train accuracy: 0.709857 val accuracy: 0.587000
# lr 6.000000e-01 reg 7.000000e-04 train accuracy: 0.706980 val accuracy: 0.594000
# lr 6.000000e-01 reg 8.000000e-04 train accuracy: 0.698592 val accuracy: 0.577000
# lr 6.000000e-01 reg 9.000000e-04 train accuracy: 0.688776 val accuracy: 0.578000
# lr 6.000000e-01 reg 1.000000e-03 train accuracy: 0.683694 val accuracy: 0.604000
# lr 6.000000e-01 reg 1.100000e-03 train accuracy: 0.684918 val accuracy: 0.596000
# lr 6.000000e-01 reg 1.200000e-03 train accuracy: 0.676245 val accuracy: 0.587000
# lr 6.000000e-01 reg 1.300000e-03 train accuracy: 0.669571 val accuracy: 0.600000
# lr 6.000000e-01 reg 1.400000e-03 train accuracy: 0.659204 val accuracy: 0.570000
# lr 7.000000e-01 reg 5.000000e-04 train accuracy: 0.711449 val accuracy: 0.575000
# lr 7.000000e-01 reg 6.000000e-04 train accuracy: 0.708796 val accuracy: 0.585000
# lr 7.000000e-01 reg 7.000000e-04 train accuracy: 0.706959 val accuracy: 0.592000
# lr 7.000000e-01 reg 8.000000e-04 train accuracy: 0.702388 val accuracy: 0.586000
# lr 7.000000e-01 reg 9.000000e-04 train accuracy: 0.696122 val accuracy: 0.595000
# lr 7.000000e-01 reg 1.000000e-03 train accuracy: 0.678918 val accuracy: 0.574000
# lr 7.000000e-01 reg 1.100000e-03 train accuracy: 0.674204 val accuracy: 0.583000
# lr 7.000000e-01 reg 1.200000e-03 train accuracy: 0.672653 val accuracy: 0.584000
# lr 7.000000e-01 reg 1.300000e-03 train accuracy: 0.672286 val accuracy: 0.567000
# lr 7.000000e-01 reg 1.400000e-03 train accuracy: 0.659714 val accuracy: 0.566000
# lr 8.000000e-01 reg 5.000000e-04 train accuracy: 0.724735 val accuracy: 0.586000
# lr 8.000000e-01 reg 6.000000e-04 train accuracy: 0.712816 val accuracy: 0.568000
# lr 8.000000e-01 reg 7.000000e-04 train accuracy: 0.715959 val accuracy: 0.595000
# lr 8.000000e-01 reg 8.000000e-04 train accuracy: 0.704673 val accuracy: 0.569000
# lr 8.000000e-01 reg 9.000000e-04 train accuracy: 0.694673 val accuracy: 0.570000
# lr 8.000000e-01 reg 1.000000e-03 train accuracy: 0.687204 val accuracy: 0.589000
# lr 8.000000e-01 reg 1.100000e-03 train accuracy: 0.675265 val accuracy: 0.584000
# lr 8.000000e-01 reg 1.200000e-03 train accuracy: 0.661041 val accuracy: 0.582000
# lr 8.000000e-01 reg 1.300000e-03 train accuracy: 0.677469 val accuracy: 0.589000
# lr 8.000000e-01 reg 1.400000e-03 train accuracy: 0.673061 val accuracy: 0.581000
# lr 9.000000e-01 reg 5.000000e-04 train accuracy: 0.735898 val accuracy: 0.590000
# lr 9.000000e-01 reg 6.000000e-04 train accuracy: 0.725490 val accuracy: 0.594000
# lr 9.000000e-01 reg 7.000000e-04 train accuracy: 0.718816 val accuracy: 0.586000
# lr 9.000000e-01 reg 8.000000e-04 train accuracy: 0.701041 val accuracy: 0.587000
# lr 9.000000e-01 reg 9.000000e-04 train accuracy: 0.702327 val accuracy: 0.588000
# lr 9.000000e-01 reg 1.000000e-03 train accuracy: 0.689041 val accuracy: 0.579000
# lr 9.000000e-01 reg 1.100000e-03 train accuracy: 0.676041 val accuracy: 0.585000
# lr 9.000000e-01 reg 1.200000e-03 train accuracy: 0.674776 val accuracy: 0.591000
# lr 9.000000e-01 reg 1.300000e-03 train accuracy: 0.667531 val accuracy: 0.593000
# lr 9.000000e-01 reg 1.400000e-03 train accuracy: 0.666184 val accuracy: 0.597000
# lr 1.000000e+00 reg 5.000000e-04 train accuracy: 0.728837 val accuracy: 0.581000
# lr 1.000000e+00 reg 6.000000e-04 train accuracy: 0.726327 val accuracy: 0.578000
# lr 1.000000e+00 reg 7.000000e-04 train accuracy: 0.715184 val accuracy: 0.603000
# lr 1.000000e+00 reg 8.000000e-04 train accuracy: 0.707755 val accuracy: 0.576000
# lr 1.000000e+00 reg 9.000000e-04 train accuracy: 0.696429 val accuracy: 0.576000
# lr 1.000000e+00 reg 1.000000e-03 train accuracy: 0.689857 val accuracy: 0.595000
# lr 1.000000e+00 reg 1.100000e-03 train accuracy: 0.676429 val accuracy: 0.579000
# lr 1.000000e+00 reg 1.200000e-03 train accuracy: 0.655020 val accuracy: 0.571000
# lr 1.000000e+00 reg 1.300000e-03 train accuracy: 0.669367 val accuracy: 0.571000
# lr 1.000000e+00 reg 1.400000e-03 train accuracy: 0.650388 val accuracy: 0.566000
# lr 1.100000e+00 reg 5.000000e-04 train accuracy: 0.737347 val accuracy: 0.589000
# lr 1.100000e+00 reg 6.000000e-04 train accuracy: 0.719857 val accuracy: 0.550000
# lr 1.100000e+00 reg 7.000000e-04 train accuracy: 0.710245 val accuracy: 0.583000
# lr 1.100000e+00 reg 8.000000e-04 train accuracy: 0.700449 val accuracy: 0.595000
# lr 1.100000e+00 reg 9.000000e-04 train accuracy: 0.695918 val accuracy: 0.579000
# lr 1.100000e+00 reg 1.000000e-03 train accuracy: 0.686959 val accuracy: 0.585000
# lr 1.100000e+00 reg 1.100000e-03 train accuracy: 0.680429 val accuracy: 0.567000
# lr 1.100000e+00 reg 1.200000e-03 train accuracy: 0.675469 val accuracy: 0.586000
# lr 1.100000e+00 reg 1.300000e-03 train accuracy: 0.663837 val accuracy: 0.593000
# lr 1.100000e+00 reg 1.400000e-03 train accuracy: 0.651755 val accuracy: 0.581000
# lr 1.200000e+00 reg 5.000000e-04 train accuracy: 0.725510 val accuracy: 0.582000
# lr 1.200000e+00 reg 6.000000e-04 train accuracy: 0.720224 val accuracy: 0.570000
# lr 1.200000e+00 reg 7.000000e-04 train accuracy: 0.698367 val accuracy: 0.572000
# lr 1.200000e+00 reg 8.000000e-04 train accuracy: 0.693429 val accuracy: 0.564000
# lr 1.200000e+00 reg 9.000000e-04 train accuracy: 0.686000 val accuracy: 0.582000
# lr 1.200000e+00 reg 1.000000e-03 train accuracy: 0.680898 val accuracy: 0.569000
# lr 1.200000e+00 reg 1.100000e-03 train accuracy: 0.677612 val accuracy: 0.586000
# lr 1.200000e+00 reg 1.200000e-03 train accuracy: 0.675327 val accuracy: 0.583000
# lr 1.200000e+00 reg 1.300000e-03 train accuracy: 0.655265 val accuracy: 0.575000
# lr 1.200000e+00 reg 1.400000e-03 train accuracy: 0.661102 val accuracy: 0.571000
# lr 1.300000e+00 reg 5.000000e-04 train accuracy: 0.728204 val accuracy: 0.582000
# lr 1.300000e+00 reg 6.000000e-04 train accuracy: 0.712102 val accuracy: 0.583000
# lr 1.300000e+00 reg 7.000000e-04 train accuracy: 0.706918 val accuracy: 0.588000
# lr 1.300000e+00 reg 8.000000e-04 train accuracy: 0.690918 val accuracy: 0.576000
# lr 1.300000e+00 reg 9.000000e-04 train accuracy: 0.692816 val accuracy: 0.590000
# lr 1.300000e+00 reg 1.000000e-03 train accuracy: 0.673571 val accuracy: 0.576000
# lr 1.300000e+00 reg 1.100000e-03 train accuracy: 0.673245 val accuracy: 0.572000
# lr 1.300000e+00 reg 1.200000e-03 train accuracy: 0.666714 val accuracy: 0.566000
# lr 1.300000e+00 reg 1.300000e-03 train accuracy: 0.660327 val accuracy: 0.577000
# lr 1.300000e+00 reg 1.400000e-03 train accuracy: 0.659102 val accuracy: 0.578000
# lr 1.400000e+00 reg 5.000000e-04 train accuracy: 0.727714 val accuracy: 0.564000
# lr 1.400000e+00 reg 6.000000e-04 train accuracy: 0.716816 val accuracy: 0.561000
# lr 1.400000e+00 reg 7.000000e-04 train accuracy: 0.707592 val accuracy: 0.570000
# lr 1.400000e+00 reg 8.000000e-04 train accuracy: 0.703939 val accuracy: 0.581000
# lr 1.400000e+00 reg 9.000000e-04 train accuracy: 0.684347 val accuracy: 0.559000
# lr 1.400000e+00 reg 1.000000e-03 train accuracy: 0.669306 val accuracy: 0.571000
# lr 1.400000e+00 reg 1.100000e-03 train accuracy: 0.667980 val accuracy: 0.582000
# lr 1.400000e+00 reg 1.200000e-03 train accuracy: 0.665796 val accuracy: 0.598000
# lr 1.400000e+00 reg 1.300000e-03 train accuracy: 0.639531 val accuracy: 0.560000
# lr 1.400000e+00 reg 1.400000e-03 train accuracy: 0.651612 val accuracy: 0.582000
# best validation accuracy achieved during cross-validation: 0.609000

# %%
# Run your neural net classifier on the test set. You should be able to
# get more than 55% accuracy.

test_acc = (net.predict(X_test_feats) == y_test).mean()
print(test_acc)
# Out:
# 0.573

# %% [markdown]
# # Bonus: Design your own features!
#
# You have seen that simple image features can improve classification performance. So far we have tried HOG and color histograms, but other types of features may be able to achieve even better classification performance.
#
# For bonus points, design and implement a new type of feature and use it for image classification on CIFAR-10. Explain how your feature works and why you expect it to be useful for image classification. Implement it in this notebook, cross-validate any hyperparameters, and compare its performance to the HOG + Color histogram baseline.

# %% [markdown]
# # Bonus: Do something extra!
# Use the material and code we have presented in this assignment to do something interesting. Was there another question we should have asked? Did any cool ideas pop into your head as you were working on the assignment? This is your chance to show off!
